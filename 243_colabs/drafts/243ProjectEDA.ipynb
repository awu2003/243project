# %% [markdown]
# #Mounting and imports

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# meta 213b
#
# meta 27b
#
# koala model
#
# vicuna 13b
#
# Databricks

# %% [markdown]
# # EDA - koala

# %%
koala13b_A100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/BAIR--koala-13b/benchmark_batch_1.json")
koala13b_V100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/V100/chat/BAIR--koala-13b/benchmark_batch_1.json")
koala13b_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/BAIR--koala-13b/benchmark_batch_1.json")

koala7b_A100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/BAIR--koala-7b/benchmark_batch_1.json")
koala7b_V100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/V100/chat/BAIR--koala-7b/benchmark_batch_1.json")
koala7b_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/BAIR--koala-7b/benchmark_batch_1.json")

# %%
koala13b_A100['input_length'] = koala13b_A100['input'].str[0].str.len()
koala13b_V100['input_length'] = koala13b_V100['input'].str[0].str.len()
koala13b_A40['input_length'] = koala13b_A40['input'].str[0].str.len()
koala7b_A100['input_length'] = koala7b_A100['input'].str[0].str.len()
koala7b_V100['input_length'] = koala7b_V100['input'].str[0].str.len()
koala7b_A40['input_length'] = koala7b_A40['input'].str[0].str.len()

koala13b_A100['output_length'] = koala13b_A100['output'].str[0].str.len()
koala13b_V100['output_length'] = koala13b_V100['output'].str[0].str.len()
koala13b_A40['output_length'] = koala13b_A40['output'].str[0].str.len()
koala7b_A100['output_length'] = koala7b_A100['output'].str[0].str.len()
koala7b_V100['output_length'] = koala7b_V100['output'].str[0].str.len()
koala7b_A40['output_length'] = koala7b_A40['output'].str[0].str.len()

# %%
koala13b_A100.corr()
# Out:
# <ipython-input-13-b2cc1caf94d5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   koala13b_A100.corr()
#                  throughput  response_length   latency    energy  \
# throughput         1.000000        -0.255572 -0.333717 -0.355193
# response_length   -0.255572         1.000000  0.991821  0.985669
# latency           -0.333717         0.991821  1.000000  0.998637
# energy            -0.355193         0.985669  0.998637  1.000000
# input_length      -0.577481         0.040229  0.111266  0.129564
# output_length     -0.218721         0.921219  0.909676  0.904106
#
#                  input_length  output_length
# throughput          -0.577481      -0.218721
# response_length      0.040229       0.921219
# latency              0.111266       0.909676
# energy               0.129564       0.904106
# ...

# %%
plt.scatter(koala7b_A100["response_length"], koala7b_A100["latency"], alpha=0.2, s=5, color="pink")
plt.scatter(koala7b_V100["response_length"], koala7b_V100["latency"], alpha=0.2, s=5, color="deeppink")
plt.scatter(koala7b_A40["response_length"], koala7b_A40["latency"], alpha=0.2, s=5, color="darkmagenta")
plt.scatter(koala13b_A100["response_length"], koala13b_A100["latency"], alpha=0.2, s=5, color="lightsteelblue")
plt.scatter(koala13b_V100["response_length"], koala13b_V100["latency"], alpha=0.2, s=5, color="cornflowerblue")
plt.scatter(koala13b_A40["response_length"], koala13b_A40["latency"], alpha=0.2, s=5, color="royalblue")

plt.legend(['Koala-7b, A100','Koala-7b, V100','Koala-7b, V40','Koala-13b, A100','Koala-13b, V100','Koala-13b, A40'], loc='upper left')


# Show the plot
plt.show()

# %%
plt.scatter(koala7b_A100["response_length"], koala7b_A100["energy"], alpha=0.2, s=5, color="pink")
plt.scatter(koala7b_V100["response_length"], koala7b_V100["energy"], alpha=0.2, s=5, color="deeppink")
plt.scatter(koala7b_A40["response_length"], koala7b_A40["energy"], alpha=0.2, s=5, color="darkmagenta")
plt.scatter(koala13b_A100["response_length"], koala13b_A100["energy"], alpha=0.2, s=5, color="lightsteelblue")
plt.scatter(koala13b_V100["response_length"], koala13b_V100["energy"], alpha=0.2, s=5, color="cornflowerblue")
plt.scatter(koala13b_A40["response_length"], koala13b_A40["energy"], alpha=0.2, s=5, color="royalblue")

plt.legend(['Koala-7b, A100','Koala-7b, V100','Koala-7b, V40','Koala-13b, A100','Koala-13b, V100','Koala-13b, A40'], loc='upper left')


# Show the plot
plt.show()

# %% [markdown]
# # Salesforce AI

# %%
salesforceAI = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/Salesforce--xgen-7b-8k-inst/benchmark_batch_1.json")
# salesforceAI_V100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/V100/chat/Salesforce--xgen-7b-8k-inst/benchmark_batch_1.json")
salesforceAI_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/Salesforce--xgen-7b-8k-inst/benchmark_batch_1.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-56fc40052d57> in <cell line: 1>()
# ----> 1 salesforceAI = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/Salesforce--xgen-7b-8k-inst/benchmark_batch_1.json")
#       2 # salesforceAI_V100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/V100/chat/Salesforce--xgen-7b-8k-inst/benchmark_batch_1.json")
#       3 salesforceAI_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/Salesforce--xgen-7b-8k-inst/benchmark_batch_1.json")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...

# %%
salesforceAI['input_length'] = salesforceAI['input'].str[0].str.len()
salesforceAI['output_length'] = salesforceAI['output'].str[0].str.len()

# salesforceAI_V100['input_length'] = salesforceAI['input'].str[0].str.len()
# salesforceAI_V100['output_length'] = salesforceAI['output'].str[0].str.len()

salesforceAI_A40['input_length'] = salesforceAI['input'].str[0].str.len()
salesforceAI_A40['output_length'] = salesforceAI['output'].str[0].str.len()

# %%
salesforceAI.corr()
# Out:
# <ipython-input-44-95d1c3df7a99>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   salesforceAI.corr()
#                  throughput  response_length   latency    energy  \
# throughput         1.000000        -0.211315 -0.225025 -0.225890
# response_length   -0.211315         1.000000  0.999487  0.998298
# latency           -0.225025         0.999487  1.000000  0.999051
# energy            -0.225890         0.998298  0.999051  1.000000
# input_length      -0.309097         0.093396  0.107640  0.135414
# output_length     -0.163515         0.910243  0.906864  0.905208
#
#                  input_length  output_length
# throughput          -0.309097      -0.163515
# response_length      0.093396       0.910243
# latency              0.107640       0.906864
# energy               0.135414       0.905208
# ...

# %%
# Plot the scatter plot
plt.scatter(salesforceAI["energy"], salesforceAI["throughput"])

# Show the plot
plt.show()

# %% [markdown]
# #Meta AI

# %%
Llama2_13b_A100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/metaai--Llama-2-13b-chat-hf/benchmark_batch_1.json")
Llama2_7b_A100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/metaai--Llama-2-7b-chat-hf/benchmark_batch_1.json")
Llama2_13b_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/metaai--Llama-2-13b-chat-hf/benchmark_batch_1.json")
Llama2_7b_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/metaai--Llama-2-7b-chat-hf/benchmark_batch_1.json")
Llama2_13b_V100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/V100/chat/metaai--Llama-2-13b-chat-hf/benchmark_batch_1.json")
Llama2_7b_V100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/V100/chat/metaai--Llama-2-7b-chat-hf/benchmark_batch_1.json")

Llama2_13b_A100['input_length'] = Llama2_13b_A100['input'].str[0].str.len()
Llama2_7b_A100['input_length'] = Llama2_7b_A100['input'].str[0].str.len()
Llama2_13b_A40['input_length'] = Llama2_13b_A40['input'].str[0].str.len()
Llama2_7b_A40['input_length'] = Llama2_7b_A40['input'].str[0].str.len()
Llama2_13b_V100['input_length'] = Llama2_13b_V100['input'].str[0].str.len()
Llama2_7b_V100['input_length'] = Llama2_7b_V100['input'].str[0].str.len()

Llama2_13b_A100['output_length'] = Llama2_13b_A100['output'].str[0].str.len()
Llama2_7b_A100['output_length'] = Llama2_7b_A100['output'].str[0].str.len()
Llama2_13b_A40['output_length'] = Llama2_13b_A40['output'].str[0].str.len()
Llama2_7b_A40['output_length'] = Llama2_7b_A40['output'].str[0].str.len()
Llama2_13b_V100['output_length'] = Llama2_13b_V100['output'].str[0].str.len()
Llama2_7b_V100['output_length'] = Llama2_7b_V100['output'].str[0].str.len()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-57fbcc74603f> in <cell line: 1>()
# ----> 1 Llama2_13b_A100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/metaai--Llama-2-13b-chat-hf/benchmark_batch_1.json")
#       2 Llama2_7b_A100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/metaai--Llama-2-7b-chat-hf/benchmark_batch_1.json")
#       3 Llama2_13b_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/metaai--Llama-2-13b-chat-hf/benchmark_batch_1.json")
#       4 Llama2_7b_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/metaai--Llama-2-7b-chat-hf/benchmark_batch_1.json")
#       5 Llama2_13b_V100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/V100/chat/metaai--Llama-2-13b-chat-hf/benchmark_batch_1.json")
#
# ...

# %%
Llama2_13b_A100
# Out:
#                             model  throughput  response_length    latency  \
# 0     metaai--Llama-2-13b-chat-hf   33.601044               34   1.011873
# 1     metaai--Llama-2-13b-chat-hf   33.621051               41   1.219474
# 2     metaai--Llama-2-13b-chat-hf   33.650434               43   1.277844
# 3     metaai--Llama-2-13b-chat-hf   33.692072               48   1.424668
# 4     metaai--Llama-2-13b-chat-hf   33.655743               42   1.247930
# ...                           ...         ...              ...        ...
# 2973  metaai--Llama-2-13b-chat-hf   25.830691              512  19.821382
# 2974  metaai--Llama-2-13b-chat-hf   26.936494              368  13.661763
# 2975  metaai--Llama-2-13b-chat-hf   26.070731              476  18.258022
# 2976  metaai--Llama-2-13b-chat-hf   26.005248              485  18.650082
# 2977  metaai--Llama-2-13b-chat-hf   28.022431              186   6.637540
#
#         energy                                              input  \
# ...

# %%
Llama2_13b_A100.corr()
# Out:
# <ipython-input-25-91fd8f0eb8cd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Llama2_13b_A100.corr()
#                  throughput  response_length   latency    energy  \
# throughput         1.000000        -0.921677 -0.936154 -0.939131
# response_length   -0.921677         1.000000  0.997981  0.997429
# latency           -0.936154         0.997981  1.000000  0.999461
# energy            -0.939131         0.997429  0.999461  1.000000
# input_length      -0.386574         0.096879  0.140839  0.151813
# output_length     -0.861426         0.938501  0.935237  0.934510
#
#                  input_length  output_length
# throughput          -0.386574      -0.861426
# response_length      0.096879       0.938501
# latency              0.140839       0.935237
# energy               0.151813       0.934510
# ...

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0, 0].hist(Llama2_13b_A100["energy"], alpha=0.5, color="c")
axes[0, 0].hist(Llama2_13b_V100["energy"], alpha=0.5, color="m")
axes[0, 0].hist(Llama2_13b_A40["energy"], alpha=0.5, color="y")
axes[0, 0].set_xlabel("Total Energy Use (J)")
axes[0, 0].set_ylabel("Count")
axes[0, 0].set_title("Llama 2 (13B)")

axes[0, 1].hist(koala13b_A100["energy"], alpha=0.5, color="c")
axes[0, 1].hist(koala13b_V100["energy"], alpha=0.5, color="m")
axes[0, 1].hist(koala13b_A40["energy"], alpha=0.5, color="y")
axes[0, 1].set_xlabel("Total Energy Use (J)")
axes[0, 1].set_ylabel("Count")
axes[0, 1].set_title("Koala (13B)")

axes[1, 0].hist(databricks_A100["energy"], alpha=0.5, color="c")
axes[1, 0].hist(databricks_V100["energy"], alpha=0.5, color="m")
axes[1, 0].hist(databricks_A40["energy"], alpha=0.5, color="y")
axes[1, 0].set_xlabel("Total Energy Use (J)")
axes[1, 0].set_ylabel("Count")
axes[1, 0].set_title("Dolly")

axes[1, 1].hist(salesforceAI["energy"], alpha=0.5, color="c")
axes[1, 1].hist(salesforceAI_A40["energy"], alpha=0.5, color="y")
axes[1, 1].set_xlabel("Total Energy Use (J)")
axes[1, 1].set_ylabel("Count")
axes[1, 1].set_title("XGen")

plt.tight_layout()

fig.legend(['A100','V100','A40'], loc='upper right')

fig.suptitle("Total Energy Use (J) by GPU", y=1.05)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-11e7a08019f5> in <cell line: 18>()
#      16 axes[0, 1].set_title("Koala (13B)")
#      17
# ---> 18 axes[1, 0].hist(databricks_A100["energy"], alpha=0.5, color="c")
#      19 axes[1, 0].hist(databricks_V100["energy"], alpha=0.5, color="m")
#      20 axes[1, 0].hist(databricks_A40["energy"], alpha=0.5, color="y")
#
# NameError: name 'databricks_A100' is not defined

# %%
column_names = ["throughput", "response_length", "latency", "output_length"]
column_labels = ["Throughput (tokens/s)", "Response Length (tokens)", "Latency (seconds)", "Output Length (characters)"]

i = 0
for col in column_names:
  if col == "input_length":
    plt.xscale('log')
  # plt.scatter(Llama2_7b_A100[col], Llama2_7b_A100["energy"], alpha=0.2, s=5, color="c")
  # plt.scatter(Llama2_7b_V100[col], Llama2_7b_V100["energy"], alpha=0.2, s=5, color="m")
  # plt.scatter(Llama2_7b_A40[col], Llama2_7b_A40["energy"], alpha=0.2, s=5, color="y")
  plt.scatter(Llama2_13b_A100[col], Llama2_13b_A100["energy"], alpha=0.2, s=5, color="c")
  plt.scatter(Llama2_13b_V100[col], Llama2_13b_V100["energy"], alpha=0.2, s=5, color="m")
  plt.scatter(Llama2_13b_A40[col], Llama2_13b_A40["energy"], alpha=0.2, s=5, color="y")

  plt.legend(['Llama 2: 13B, A100','Llama 2: 13B, V100','Llama 2: 13B, A40'], loc='upper left')

  plt.xlabel(column_labels[i])
  plt.ylabel("Total Energy Use (J)")
  plt.title(column_labels[i] + " vs. Total Energy Use (J) for Llama 2 by GPU")
  plt.show()
  i += 1

# %%
plt.scatter(Llama2_7b_A100["response_length"], Llama2_7b_A100["throughput"], alpha=0.2, s=5, color="pink")

# %% [markdown]
# # Databricks

# %%
databricks_A100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/databricks--dolly-v2-12b/benchmark_batch_1.json")
databricks_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/databricks--dolly-v2-12b/benchmark_batch_1.json")
databricks_V100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/V100/chat/databricks--dolly-v2-12b/benchmark_batch_1.json")

databricks_A100['input_length'] = databricks_A100['input'].str[0].str.len()
databricks_A40['input_length'] = databricks_A40['input'].str[0].str.len()
databricks_V100['input_length'] = databricks_V100['input'].str[0].str.len()

databricks_A100['output_length'] = databricks_A100['output'].str[0].str.len()
databricks_A40['output_length'] = databricks_A40['output'].str[0].str.len()
databricks_V100['output_length'] = databricks_V100['output'].str[0].str.len()

# %%
databricks_A100.corr()
# Out:
# <ipython-input-32-9314bd35936c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   databricks_A100.corr()
#                  throughput  response_length   latency    energy  \
# throughput         1.000000         0.335967  0.329571  0.317598
# response_length    0.335967         1.000000  0.999718  0.996555
# latency            0.329571         0.999718  1.000000  0.997579
# energy             0.317598         0.996555  0.997579  1.000000
# input_length      -0.217822         0.169797  0.183831  0.228324
# output_length      0.309874         0.874510  0.873917  0.869639
#
#                  input_length  output_length
# throughput          -0.217822       0.309874
# response_length      0.169797       0.874510
# latency              0.183831       0.873917
# energy               0.228324       0.869639
# ...

# %%
column_names = ["input_length", "throughput", "response_length", "latency"]

for col in column_names:
  if col == "input_length":
    plt.xscale('log')
  plt.scatter(databricks_A100[col], databricks_A100["energy"], alpha=0.2, s=5, color="pink")
  plt.scatter(databricks_V100[col], databricks_V100["energy"], alpha=0.2, s=5, color="deeppink")
  plt.scatter(databricks_A40[col], databricks_A40["energy"], alpha=0.2, s=5, color="darkmagenta")

  plt.legend(['databricks_A100','databricks_V100','databricks_A40'], loc='upper left')

  plt.xlabel(col)
  plt.ylabel("energy")
  plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Analysis across models

# %%
databricks_A100 = databricks_A100[databricks_A100["output_length"] < 3000]
koala13b_A100 = koala13b_A100[koala13b_A100["output_length"] < 3000]

column_names = ["throughput", "response_length", "latency", "output_length"]
column_labels = ["Throughput (tokens/s)", "Response Length (tokens)", "Latency (seconds)", "Output Length (characters)"]

i = 0
for col in column_names:
  if col == "input_length":
    plt.xscale('log')
  plt.scatter(Llama2_13b_A100[col], Llama2_13b_A100["energy"], alpha=0.2, s=5, color="red")
  plt.scatter(koala13b_A100[col], koala13b_A100["energy"], alpha=0.2, s=5, color="blue")
  plt.scatter(databricks_A100[col], databricks_A100["energy"], alpha=0.2, s=5, color="green")
  plt.scatter(salesforceAI[col], salesforceAI["energy"], alpha=0.2, s=5, color="orange")

  plt.legend(['Llama 2 (13B)','Koala (13B)','Dolly', 'XGen'], loc='upper left')

  plt.xlabel(column_labels[i])
  plt.ylabel("Total Energy Use (J)")
  plt.title(column_labels[i] + " vs. Total Energy Use (J) for LLMs")
  plt.show()
  i += 1

# %%
print(len(Llama2_13b_A100[Llama2_13b_V100["response_length"] == 512]) / len(Llama2_13b_A100))
print(len(koala13b_A100[Llama2_13b_V100["response_length"] == 512]) / len(koala13b_A100))
print(len(databricks_A100[Llama2_13b_V100["response_length"] == 512]) / len(databricks_A100))
print(len(salesforceAI[Llama2_13b_V100["response_length"] == 512]) / len(salesforceAI))
# Out:
# 0.45533915379449297
# 0.45527908540685946
# 0.45564516129032256
# 0.45533915379449297
# <ipython-input-35-6efef3fca99c>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(koala13b_A100[Llama2_13b_V100["response_length"] == 512]) / len(koala13b_A100))
# <ipython-input-35-6efef3fca99c>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(databricks_A100[Llama2_13b_V100["response_length"] == 512]) / len(databricks_A100))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
plt.scatter(Llama2_13b_A100["response_length"], Llama2_13b_A100["throughput"], alpha=0.2, s=5, color="red")
plt.scatter(koala13b_A100["response_length"], koala13b_A100["throughput"], alpha=0.2, s=5, color="blue")
plt.scatter(databricks_A100["response_length"], databricks_A100["throughput"], alpha=0.2, s=5, color="green")
plt.scatter(salesforceAI["response_length"], salesforceAI["throughput"], alpha=0.2, s=5, color="orange")

plt.legend(['Llama 2 (13B)','Koala (13B)','Dolly', 'XGen'], loc='upper left')

plt.xlabel("Response Length (tokens)")
plt.ylabel("Throughput (tokens/s)")
plt.title("Response Length (tokens)" + " vs. Throughput (tokens/s) for LLMs")
plt.show()

# %%
plt.scatter(Llama2_13b_A100["input_length"], Llama2_13b_A100["response_length"], alpha=0.2, s=5, color="red")
plt.scatter(koala13b_A100["input_length"], koala13b_A100["response_length"], alpha=0.2, s=5, color="blue")
plt.scatter(databricks_A100["input_length"], databricks_A100["response_length"], alpha=0.2, s=5, color="green")
plt.scatter(salesforceAI["input_length"], salesforceAI["response_length"], alpha=0.2, s=5, color="orange")

plt.legend(['Llama 2 (13B)','Koala (13B)','Dolly', 'XGen'], loc='upper left')

plt.xlabel("Input Length (characters)")
plt.ylabel("Response Length (tokens)")
plt.title("Input Length (characters)" + " vs. Response Length (tokens)")
plt.show()

# %%
1import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
Llama2_13b_A100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/metaai--Llama-2-13b-chat-hf/benchmark_batch_1.json")
Llama2_7b_A100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A100/chat/metaai--Llama-2-7b-chat-hf/benchmark_batch_1.json")
Llama2_13b_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/metaai--Llama-2-13b-chat-hf/benchmark_batch_1.json")
Llama2_7b_A40 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/A40/chat/metaai--Llama-2-7b-chat-hf/benchmark_batch_1.json")
Llama2_13b_V100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/V100/chat/metaai--Llama-2-13b-chat-hf/benchmark_batch_1.json")
Llama2_7b_V100 = pd.read_json("/content/gdrive/MyDrive/benchmarks_bs1/V100/chat/metaai--Llama-2-7b-chat-hf/benchmark_batch_1.json")


Llama2_13b_A100['input_length'] = Llama2_13b_A100['input'].str[0].str.len()
X = Llama2_13b_A100['input_length']
y = Llama2_13b_A100['energy']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
plt.scatter(Llama2_13b_A100['input_length'], Llama2_13b_A100['energy'], alpha=0.2)
plt.plot(Llama2_13b_A100['input_length'], model.predict(X), color='red')  # Regression line
plt.xlabel('Input Length Token')
plt.ylabel('Energy')
plt.title('Linear Regression: Energy vs Input Length')
plt.show()

Llama2_13b_A100['input_length'] = Llama2_13b_A100['input'].str[0].str.len()
Llama2_13b_A100['output_length'] = Llama2_13b_A100['output'].str[0].str.len()
X = Llama2_13b_A100['input_length']
y = Llama2_13b_A100['output_length']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
plt.scatter(Llama2_13b_A100['input_length'], Llama2_13b_A100['output_length'], alpha=0.2)
plt.plot(Llama2_13b_A100['input_length'], model.predict(X), color='red')  # Regression line
plt.xlabel('Input Length(Token)')
plt.ylabel('Output Length (Token)')
plt.title('Linear Regression: Output Length vs Input Length')
plt.show()

Llama2_13b_A100['input_length'] = Llama2_13b_A100['input'].str[0].str.len()
Llama2_13b_A100['output_length'] = Llama2_13b_A100['output'].str[0].str.len()
X = Llama2_13b_A100['output_length']
y = Llama2_13b_A100['energy']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
plt.scatter(Llama2_13b_A100['output_length'], Llama2_13b_A100['energy'], alpha=0.2)
plt.plot(Llama2_13b_A100['output_length'], model.predict(X), color='red')  # Regression line
plt.xlabel('Output')
plt.ylabel('Energy')
plt.title('Linear Regression: Energy vs Output Length')
plt.show()

X = Llama2_13b_A100['response_length']
y = Llama2_13b_A100['energy']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
Llama2_13b_A100['residuals'] = Llama2_13b_A100['energy'] - model.predict(X)
outliers = Llama2_13b_A100[abs(Llama2_13b_A100['residuals']) > 200]
print(outliers)
plt.scatter(Llama2_13b_A100['response_length'], Llama2_13b_A100['energy'], alpha=0.2)
plt.plot(Llama2_13b_A100['response_length'], model.predict(X), color='red')  # Regression line
plt.scatter(outliers['response_length'], outliers['energy'], color='green')  # Outliers
plt.xlabel('Output')
plt.ylabel('Energy')
plt.title('Linear Regression: Energy vs Output Length')
plt.show()

column_names = ["throughput", "response_length", "latency", "output_length"]
column_labels = ["Throughput (tokens/s)", "Response Length (tokens)", "Latency (seconds)", "Output Length (characters)"]

i = 0
for col in column_names:
  if col == "input_length":
    plt.xscale('log')
  # plt.scatter(Llama2_7b_A100[col], Llama2_7b_A100["energy"], alpha=0.2, s=5, color="c")
  # plt.scatter(Llama2_7b_V100[col], Llama2_7b_V100["energy"], alpha=0.2, s=5, color="m")
  # plt.scatter(Llama2_7b_A40[col], Llama2_7b_A40["energy"], alpha=0.2, s=5, color="y")
  plt.scatter(Llama2_13b_A100[col], Llama2_13b_A100["energy"], alpha=0.2, s=5, color="c")
  plt.scatter(Llama2_13b_V100[col], Llama2_13b_V100["energy"], alpha=0.2, s=5, color="m")
  plt.scatter(Llama2_13b_A40[col], Llama2_13b_A40["energy"], alpha=0.2, s=5, color="y")

  plt.legend(['Llama 2: 13B, A100','Llama 2: 13B, V100','Llama 2: 13B, A40'], loc='upper left')

  plt.xlabel(column_labels[i])
  plt.ylabel("Total Energy Use (J)")
  plt.title(column_labels[i] + " vs. Total Energy Use (J) for Llama 2 by GPU")
  plt.show()
  i += 1
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 energy   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     70.21
# Date:                Tue, 05 Dec 2023   Prob (F-statistic):           8.12e-17
# Time:                        21:23:05   Log-Likelihood:                -25704.
# No. Observations:                2978   AIC:                         5.141e+04
# Df Residuals:                    2976   BIC:                         5.142e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         2919.7827     29.326     99.564      0.000    2862.282    2977.283
# ...

# %% [markdown]
# # actual modeling code

# %%
# Llama2_13b_A100['response_length'] = Llama2_13b_A100['input'].str[0].str.len()
# Llama2_13b_A100['energy'] = Llama2_13b_A100['output'].str[0].str.len()
X = Llama2_13b_A100['response_length']
y = Llama2_13b_A100['energy']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
plt.scatter(Llama2_13b_A100['response_length'], Llama2_13b_A100['energy'], alpha=0.2)
plt.plot(Llama2_13b_A100['response_length'], model.predict(X), color='red')  # Regression line
plt.xlabel('Input Length(Token)')
plt.ylabel('Output Length (Token)')
plt.title('Linear Regression: Output Length vs Input Length')
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 energy   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 5.765e+05
# Date:                Tue, 05 Dec 2023   Prob (F-statistic):               0.00
# Time:                        21:26:12   Log-Likelihood:                -17889.
# No. Observations:                2978   AIC:                         3.578e+04
# Df Residuals:                    2976   BIC:                         3.579e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -78.4825      4.497    -17.451      0.000     -87.301     -69.664
# ...

# %%
outliers = Llama2_13b_A100[abs(Llama2_13b_A100['residuals']) > 200]

plt.hist(Llama2_13b_A100['residuals'], bins=100)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   0.,   1.,   0.,   1.,   0.,   1.,
#           0.,   4.,   5.,  24.,  32.,  48.,  61.,  72., 116., 142., 211.,
#         183., 192., 207., 237., 276., 240., 185., 149., 124.,  91.,  78.,
#          58.,  40.,  31.,  15.,   6.,   5.,   5.,   6.,   2.,   3.,   3.,
#           2.,   1.,   2.,   1.,   5.,   2.,   1.,   5.,   6.,   1.,   2.,
#           3.,   1.,   1.,   1.,   3.,   4.,   2.,   2.,   2.,   0.,   0.,
#           2.,   2.,   4.,   1.,   2.,   2.,   1.,   2.,   1.,   1.,   3.,
#           1.,   0.,   2.,   2.,   2.,   1.,   3.,   2.,   1.,   3.,   4.,
#           1.,   2.,   2.,   4.,   0.,   0.,   2.,   5.,  10.,   3.,   3.,
#           2.]),
#  array([-239.65312177, -230.90577177, -222.15842177, -213.41107177,
#         -204.66372177, -195.91637177, -187.16902177, -178.42167177,
#         -169.67432177, -160.92697177, -152.17962177, -143.43227177,
#         -134.68492177, -125.93757177, -117.19022177, -108.44287177,
# ...

# %%
non_outliers = Llama2_13b_A100[abs(Llama2_13b_A100['residuals']) < 150]

X = non_outliers['response_length']
y = non_outliers['energy']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())

plt.scatter(Llama2_13b_A100['response_length'], Llama2_13b_A100['energy'], alpha=0.2)
plt.plot(non_outliers['response_length'], model.predict(X), color='red')  # Regression line
plt.xlabel('Input Length(Token)')
plt.ylabel('Output Length (Token)')
plt.title('Linear Regression: Output Length vs Input Length')
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 energy   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.892e+06
# Date:                Tue, 05 Dec 2023   Prob (F-statistic):               0.00
# Time:                        21:35:48   Log-Likelihood:                -14859.
# No. Observations:                2867   AIC:                         2.972e+04
# Df Residuals:                    2865   BIC:                         2.973e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -72.7931      1.982    -36.730      0.000     -76.679     -68.907
# ...

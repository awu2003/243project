# %% [markdown]
# # Imports and Mounting

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from scipy.stats import beta

from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Downloading all files

# %% [markdown]
# ## Iterating through A100

# %%
# %cd '/content/gdrive/MyDrive/benchmarks_bs1/A100/chat'
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-148-d2109ada4937>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', "'/content/gdrive/MyDrive/benchmarks_bs1/A100/chat'")
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-148-d2109ada4937>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', "'/content/gdrive/MyDrive/benchmarks_bs1/A100/chat'")
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-148-d2109ada4937>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', "'/content/gdrive/MyDrive/benchmarks_bs1/A100/chat'")
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
A100_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-148-3a93c2570f8a>", line 1, in <cell line: 1>
#     A100_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-148-3a93c2570f8a>", line 1, in <cell line: 1>
#     A100_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-148-3a93c2570f8a>", line 1, in <cell line: 1>
#     A100_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
A100_subfolders
# Out:
# ['./h2oai--h2ogpt-gm-oasst1-en-2048-open-llama-7b-preview-300bt-v2',
#  './tatsu-lab--alpaca-7B',
#  './project-baize--baize-v2-7B',
#  './metaai--llama-13B',
#  './openaccess-ai-collective--manticore-13b-chat-pyg',
#  './BAIR--koala-7b',
#  './lmsys--vicuna-7B',
#  './Neutralzz--BiLLa-7B-SFT',
#  './BAIR--koala-13b',
#  './nomic-ai--gpt4all-13b-snoozy',
#  './togethercomputer--RedPajama-INCITE-7B-Chat',
#  './OpenAssistant--oasst-sft-1-pythia-12b',
#  './camel-ai--CAMEL-13B-Combined-Data',
#  './metaai--llama-7B',
#  './Salesforce--xgen-7b-8k-inst',
#  './FreedomIntelligence--phoenix-inst-chat-7b',
#  './StabilityAI--stablelm-tuned-alpha-7b',
#  './metaai--Llama-2-7b-chat-hf',
#  './metaai--Llama-2-13b-chat-hf',
#  './databricks--dolly-v2-12b',
#  './lmsys--vicuna-13B',
#  './lmsys--fastchat-t5-3b-v1.0']

# %%
A100_files = {}

for folder in A100_subfolders:
    files = os.listdir(folder)
    for file in files:
        file_path = os.path.join(folder, file)
        print(f"Processing file: {file_path}")
        # Do something with the file, e.g., open and read its contents
        with open(file_path, 'r') as f:
            A100_files[folder] = {}
            A100_files[folder]['model'] = pd.read_json(f)
            # Process the content as needed
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-2e08a22c5134>", line 4, in <cell line: 3>
#     files = os.listdir(folder)
# OSError: [Errno 107] Transport endpoint is not connected: './h2oai--h2ogpt-gm-oasst1-en-2048-open-llama-7b-preview-300bt-v2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-2e08a22c5134>", line 4, in <cell line: 3>
#     files = os.listdir(folder)
# OSError: [Errno 107] Transport endpoint is not connected: './h2oai--h2ogpt-gm-oasst1-en-2048-open-llama-7b-preview-300bt-v2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-2e08a22c5134>", line 4, in <cell line: 3>
#     files = os.listdir(folder)
# OSError: [Errno 107] Transport endpoint is not connected: './h2oai--h2ogpt-gm-oasst1-en-2048-open-llama-7b-preview-300bt-v2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# ## Iterating through A40

# %%
# %cd '/content/gdrive/MyDrive/benchmarks_bs1/A40/chat'
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-105b7069dc78>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', "'/content/gdrive/MyDrive/benchmarks_bs1/A40/chat'")
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-105b7069dc78>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', "'/content/gdrive/MyDrive/benchmarks_bs1/A40/chat'")
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-105b7069dc78>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', "'/content/gdrive/MyDrive/benchmarks_bs1/A40/chat'")
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
A40_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-e3b91276671d>", line 1, in <cell line: 1>
#     A40_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-e3b91276671d>", line 1, in <cell line: 1>
#     A40_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-e3b91276671d>", line 1, in <cell line: 1>
#     A40_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
A40_files = {}

for folder in A40_subfolders:
    files = os.listdir(folder)
    for file in files:
        file_path = os.path.join(folder, file)
        print(f"Processing file: {file_path}")
        # Do something with the file, e.g., open and read its contents
        with open(file_path, 'r') as f:
            A40_files[folder] = {}
            A40_files[folder]['model'] = pd.read_json(f)
            # Process the content as needed
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-084e395376fc>", line 4, in <cell line: 3>
#     files = os.listdir(folder)
# OSError: [Errno 107] Transport endpoint is not connected: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-084e395376fc>", line 4, in <cell line: 3>
#     files = os.listdir(folder)
# OSError: [Errno 107] Transport endpoint is not connected: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-149-084e395376fc>", line 4, in <cell line: 3>
#     files = os.listdir(folder)
# OSError: [Errno 107] Transport endpoint is not connected: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
A40_files.keys()
# Out:
# dict_keys([])

# %% [markdown]
# ## Iterating through V100

# %%
# %cd '/content/gdrive/MyDrive/benchmarks_bs1/V100/chat'
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-150-b182db0cc9de>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', "'/content/gdrive/MyDrive/benchmarks_bs1/V100/chat'")
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-150-b182db0cc9de>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', "'/content/gdrive/MyDrive/benchmarks_bs1/V100/chat'")
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-150-b182db0cc9de>", line 1, in <cell line: 1>
#     get_ipython().run_line_magic('cd', "'/content/gdrive/MyDrive/benchmarks_bs1/V100/chat'")
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
V100_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-150-56e59c68e07d>", line 1, in <cell line: 1>
#     V100_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-150-56e59c68e07d>", line 1, in <cell line: 1>
#     V100_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-150-56e59c68e07d>", line 1, in <cell line: 1>
#     V100_subfolders = [f.path for f in os.scandir() if f.is_dir()]
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
V100_files = {}

for folder in V100_subfolders:
    files = os.listdir(folder)
    for file in files:
        file_path = os.path.join(folder, file)
        print(f"Processing file: {file_path}")
        # Do something with the file, e.g., open and read its contents
        with open(file_path, 'r') as f:
            V100_files[folder] = {}
            V100_files[folder]['model'] = pd.read_json(f)
            # Process the content as needed
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-150-c921848e5942>", line 4, in <cell line: 3>
#     files = os.listdir(folder)
# OSError: [Errno 107] Transport endpoint is not connected: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-150-c921848e5942>", line 4, in <cell line: 3>
#     files = os.listdir(folder)
# OSError: [Errno 107] Transport endpoint is not connected: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-150-c921848e5942>", line 4, in <cell line: 3>
#     files = os.listdir(folder)
# OSError: [Errno 107] Transport endpoint is not connected: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# # How to use this notebook
#
# - file names are stored in ```{GPU}_Subfolders```
# - to access the associated model use the format ```{GPU}_files[{GPU}_Subfolders]['model']```

# %% [markdown]
# # Functions for modeling and graphing

# %%
def plot_length_energy(dictionary, model_name, color='c'):
  model_data = dictionary[model_name]['model']

  plt.scatter(model_data["response_length"], model_data["energy"], alpha=0.2, s=5, color=color)
  plt.legend([model_name], loc='upper left')
  plt.show()

# %%
def make_linear_model(dictionary, model_name):
  model_data = dictionary[model_name]['model']

  X = model_data["response_length"]
  y = model_data["energy"]

  #X = sm.add_constant(X)

  model = sm.OLS(y, X).fit()

  dictionary[model_name]['linear X'] = model.params[0]

  return model

# %%
def make_quadratic_model(dictionary, model_name):
  model_data = dictionary[model_name]['model']

  X = model_data["response_length"]
  y = model_data["energy"]

  df = pd.DataFrame({'X': X, 'X_squared': X**2, 'y': y})
  #X_quad = sm.add_constant(df[['X', 'X_squared']])

  model = sm.OLS(df['y'], df[['X', 'X_squared']]).fit()

  dictionary[model_name]['quad X'] = model.params[0]
  dictionary[model_name]['quad X2'] = model.params[1]

  return model

# %%
def plot_resid(model):
  # Obtain residuals
  residuals = model.resid

  # Plot residuals
  plt.scatter(model.fittedvalues, residuals)
  plt.xlabel('Fitted values')
  plt.ylabel('Residuals')
  plt.title('Residual Plot')
  plt.axhline(y=0, color='r', linestyle='--')  # Add a horizontal line at y=0 for reference
  plt.show()

# %%
# plots all positive residuals which are above 1.5 * std of residuals

def plot_outliers(model, plot=True, std=1.5, intercept=False):
  residuals = model.resid

  outliers = residuals > std * np.std(residuals) # You can adjust the threshold as needed

  # Subset the second series based on the first series
  subset_values = residuals[outliers]

  if plot:
    # Plot residuals
    plt.scatter(model.fittedvalues[outliers], subset_values)
    plt.xlabel('Fitted values')
    plt.ylabel('Residuals')
    plt.title('Residual Plot')
    plt.axhline(y=0, color='r', linestyle='--')  # Add a horizontal line at y=0 for reference
    plt.show()

  X = model.fittedvalues[outliers]
  y = subset_values

  resid_model = sm.OLS(y, X).fit()

  return model.fittedvalues[outliers], subset_values, resid_model

# %%
def plot_nonoutliers(model, plot=True, std=1.5):
  residuals = model.resid

  nonoutliers = np.abs(residuals) < std * np.std(residuals)  # You can adjust the threshold as needed

  # Subset the second series based on the first series
  subset_values = residuals[nonoutliers]

  return model.fittedvalues[nonoutliers], subset_values

# %% [markdown]
# # Plotting work

# %%
for name in A100_subfolders:
  plot_length_energy(A100_files, name, 'c')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-490a9b480220>", line 2, in <cell line: 1>
#     plot_length_energy(A100_files, name, 'c')
#   File "<ipython-input-126-8df794398a81>", line 2, in plot_length_energy
#     model_data = dictionary[model_name]['model']
# KeyError: './h2oai--h2ogpt-gm-oasst1-en-2048-open-llama-7b-preview-300bt-v2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-490a9b480220>", line 2, in <cell line: 1>
#     plot_length_energy(A100_files, name, 'c')
#   File "<ipython-input-126-8df794398a81>", line 2, in plot_length_energy
#     model_data = dictionary[model_name]['model']
# KeyError: './h2oai--h2ogpt-gm-oasst1-en-2048-open-llama-7b-preview-300bt-v2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-490a9b480220>", line 2, in <cell line: 1>
#     plot_length_energy(A100_files, name, 'c')
#   File "<ipython-input-126-8df794398a81>", line 2, in plot_length_energy
#     model_data = dictionary[model_name]['model']
# KeyError: './h2oai--h2ogpt-gm-oasst1-en-2048-open-llama-7b-preview-300bt-v2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
for name in A40_subfolders:
  plot_length_energy(A40_files, name, 'm')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-6dca2528c916>", line 2, in <cell line: 1>
#     plot_length_energy(A40_files, name, 'm')
#   File "<ipython-input-126-8df794398a81>", line 2, in plot_length_energy
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-6dca2528c916>", line 2, in <cell line: 1>
#     plot_length_energy(A40_files, name, 'm')
#   File "<ipython-input-126-8df794398a81>", line 2, in plot_length_energy
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-6dca2528c916>", line 2, in <cell line: 1>
#     plot_length_energy(A40_files, name, 'm')
#   File "<ipython-input-126-8df794398a81>", line 2, in plot_length_energy
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
for name in V100_subfolders:
  plot_length_energy(V100_files, name, 'y')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-97781e4a1e63>", line 2, in <cell line: 1>
#     plot_length_energy(V100_files, name, 'y')
#   File "<ipython-input-126-8df794398a81>", line 2, in plot_length_energy
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-97781e4a1e63>", line 2, in <cell line: 1>
#     plot_length_energy(V100_files, name, 'y')
#   File "<ipython-input-126-8df794398a81>", line 2, in plot_length_energy
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-97781e4a1e63>", line 2, in <cell line: 1>
#     plot_length_energy(V100_files, name, 'y')
#   File "<ipython-input-126-8df794398a81>", line 2, in plot_length_energy
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# # modeling

# %% [markdown]
# # V100
#
# Focusing on the V100 because of the lack of multileveling (as observed in the A100)

# %%
for name in V100_subfolders:
  print(name)
  current = make_quadratic_model(V100_files, name)
  print(current.summary())
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ./project-baize--baize-v2-7B
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-b5c11d46eeef>", line 3, in <cell line: 1>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-b5c11d46eeef>", line 3, in <cell line: 1>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-b5c11d46eeef>", line 3, in <cell line: 1>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
for name in V100_subfolders:
  print(name)
  current = make_quadratic_model(V100_files, name)
  x, y = plot_nonoutliers(current, plot=True, std=1)

  plt.scatter(x, y)
  plt.show()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ./project-baize--baize-v2-7B
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-fd1f9b45f7fa>", line 3, in <cell line: 1>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-fd1f9b45f7fa>", line 3, in <cell line: 1>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-fd1f9b45f7fa>", line 3, in <cell line: 1>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
for name in A40_subfolders:
  print(name)
  current = make_quadratic_model(A40_files, name)
  plot_resid(current)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ./BAIR--koala-7b
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-9ea22e7ba776>", line 3, in <cell line: 1>
#     current = make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-9ea22e7ba776>", line 3, in <cell line: 1>
#     current = make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-132-9ea22e7ba776>", line 3, in <cell line: 1>
#     current = make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
V100_subfolders

# %%
name = './project-baize--baize-v2-7B'

model = make_quadratic_model(V100_files, name)

plot_resid(model)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-ad846d50288a>", line 3, in <cell line: 3>
#     model = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-ad846d50288a>", line 3, in <cell line: 3>
#     model = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-ad846d50288a>", line 3, in <cell line: 3>
#     model = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# # dealing w resids

# %%
for name in V100_subfolders:
  print(name)
  current = make_quadratic_model(V100_files, name)
  plot_resid(current)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ./project-baize--baize-v2-7B
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-cb6f8c7da46f>", line 3, in <cell line: 1>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-cb6f8c7da46f>", line 3, in <cell line: 1>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-cb6f8c7da46f>", line 3, in <cell line: 1>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
for name in A40_subfolders:
  print(name)
  current = make_quadratic_model(A40_files, name)
  x_linspace, outliers, model = plot_outliers(current, False, std=1.5)

  plt.scatter(x_linspace, outliers)
  plt.xlabel('Fitted values')
  plt.ylabel('Residuals')
  plt.title('Residual Plot')


  # Plot the line
  plt.plot(x_linspace, model.fittedvalues)

  plt.show()

  print(model.summary())
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ./BAIR--koala-7b
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-2d64fe1f1360>", line 3, in <cell line: 1>
#     current = make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-2d64fe1f1360>", line 3, in <cell line: 1>
#     current = make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-2d64fe1f1360>", line 3, in <cell line: 1>
#     current = make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# # attempt at full model
#
# steps:
#
# - make quadratic model and get coefficients
# - find distribution of residuals
# - predict parameters of beta distribution from coefficients of quadratic

# %%
for name in A40_subfolders:
  print(name)
  current = make_linear_model(A40_files, name)
  print("linear")
  print(current.params)
  current = make_quadratic_model(A40_files, name)
  print("quad")
  print(current.params)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ./BAIR--koala-7b
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-6e7a00da9dcc>", line 3, in <cell line: 1>
#     current = make_linear_model(A40_files, name)
#   File "<ipython-input-127-0147fb44fb80>", line 2, in make_linear_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-6e7a00da9dcc>", line 3, in <cell line: 1>
#     current = make_linear_model(A40_files, name)
#   File "<ipython-input-127-0147fb44fb80>", line 2, in make_linear_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-133-6e7a00da9dcc>", line 3, in <cell line: 1>
#     current = make_linear_model(A40_files, name)
#   File "<ipython-input-127-0147fb44fb80>", line 2, in make_linear_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
current.params[0]

# %%
model_info = {}

for name in V100_subfolders:
  name_gpu = name + "V100" # add gpu to end of name
  model_info[name_gpu] = {} # create empty dict

  # add gpu
  model_info[name_gpu]['gpu'] = "V100"

  # make quad model
  current = make_quadratic_model(V100_files, name)
  model_info[name_gpu]['X_coef'] = current.params[0]
  model_info[name_gpu]['X_squared_coef'] = current.params[1]

  # get outliers and fit beta
  outliers = plot_outliers(current, False)

  params = beta.fit(outliers) # Fit a beta distribution to the data
  print(params) # Print the parameters of the fitted distribution
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-b9c6d646dfb4>", line 11, in <cell line: 3>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-b9c6d646dfb4>", line 11, in <cell line: 3>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-b9c6d646dfb4>", line 11, in <cell line: 3>
#     current = make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
print(name)
current = make_quadratic_model(A40_files, name)
x_linspace, outliers, model = plot_outliers(current, False, std=1.5)


# Obtain residuals
residuals = model.resid

# Plot residuals
plt.scatter(model.fittedvalues, residuals)
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.axhline(y=0, color='r', linestyle='--')  # Add a horizontal line at y=0 for reference


plt.scatter(x_linspace, outliers)
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
plt.title('Residual Plot')

# Plot the line
plt.plot(x_linspace, model.fittedvalues)

plt.show()

print(model.summary())
# Out:
# ./project-baize--baize-v2-7B
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-222fe4f6351b>", line 2, in <cell line: 2>
#     current = make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-222fe4f6351b>", line 2, in <cell line: 2>
#     current = make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-222fe4f6351b>", line 2, in <cell line: 2>
#     current = make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
import statsmodels.api as sm
import numpy as np

model_data = A40_files["./project-baize--baize-v2-7B"]['model']

X = model_data["response_length"]
y = model_data["energy"]


X_with_const = sm.add_constant(X)
weights = 1 / X
wls_model = sm.WLS(y, X_with_const, weights=weights).fit()
variance = X**2
sigma_matrix = np.diag(variance)
gls_model = sm.GLS(y, X_with_const, sigma=sigma_matrix).fit()
y_pred_wls = wls_model.predict(X_with_const)
y_pred_gls = gls_model.predict(X_with_const)

plt.figure(figsize=(10, 5))
plt.scatter(X, y, label='Actual values', alpha=0.5)
plt.scatter(X, y_pred_wls, label='WLS Predicted values', alpha=0.5)
plt.title('WLS Model Fit')
plt.xlabel('Response Length')
plt.ylabel('Energy')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.scatter(X, y, label='Actual values', alpha=0.5)
plt.scatter(X, y_pred_gls, label='GLS Predicted values', alpha=0.5)
plt.title('GLS Model Fit')
plt.xlabel('Response Length')
plt.ylabel('Energy')
plt.legend()
plt.show()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-bf63dd7502a1>", line 4, in <cell line: 4>
#     model_data = A40_files["./project-baize--baize-v2-7B"]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-bf63dd7502a1>", line 4, in <cell line: 4>
#     model_data = A40_files["./project-baize--baize-v2-7B"]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-bf63dd7502a1>", line 4, in <cell line: 4>
#     model_data = A40_files["./project-baize--baize-v2-7B"]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# # predicting slope from architecture

# %% [markdown]
# ## storing coefficients

# %%
for name in V100_subfolders:
  make_quadratic_model(V100_files, name)
  make_linear_model(V100_files, name)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-20f962e10012>", line 2, in <cell line: 1>
#     make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-20f962e10012>", line 2, in <cell line: 1>
#     make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-20f962e10012>", line 2, in <cell line: 1>
#     make_quadratic_model(V100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './project-baize--baize-v2-7B'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
for name in A100_subfolders:
  make_quadratic_model(A100_files, name)
  make_linear_model(A100_files, name)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-03b60d4c4633>", line 2, in <cell line: 1>
#     make_quadratic_model(A100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './h2oai--h2ogpt-gm-oasst1-en-2048-open-llama-7b-preview-300bt-v2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-03b60d4c4633>", line 2, in <cell line: 1>
#     make_quadratic_model(A100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './h2oai--h2ogpt-gm-oasst1-en-2048-open-llama-7b-preview-300bt-v2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-03b60d4c4633>", line 2, in <cell line: 1>
#     make_quadratic_model(A100_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './h2oai--h2ogpt-gm-oasst1-en-2048-open-llama-7b-preview-300bt-v2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
for name in A40_subfolders:
  make_quadratic_model(A40_files, name)
  make_linear_model(A40_files, name)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-a0d470c6849b>", line 2, in <cell line: 1>
#     make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-a0d470c6849b>", line 2, in <cell line: 1>
#     make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-134-a0d470c6849b>", line 2, in <cell line: 1>
#     make_quadratic_model(A40_files, name)
#   File "<ipython-input-128-223ff163e864>", line 2, in make_quadratic_model
#     model_data = dictionary[model_name]['model']
# KeyError: './BAIR--koala-7b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# ## importing dataframe

# %%
llm_data = pd.read_csv("/content/gdrive/MyDrive/benchmarks_bs1/243 model data - Sheet1.csv")
llm_data

# %%
llm_A40 = llm_data.copy()
llm_A40['gpu model'] = "A40"

# %%
llm_A100 = llm_data.copy()
llm_A100['gpu model'] = "A100"

# %%
llm_V100 = llm_data.copy()
llm_V100['gpu model'] = "V100"

# %% [markdown]
# #hi

# %%
llm_V100

# %%
[x for x in A40_subfolders if llm_data['Model name'].str.contains(x[2:]).any()]

# %%
[x for x in A100_subfolders if llm_data['Model name'].str.contains(x[2:]).any()]

# %%
[x for x in V100_subfolders if llm_data['Model name'].str.contains(x[2:]).any()]

# %% [markdown]
# ## combining dataframes

# %%
def combine_dfs(dictionary, df):
  dict_df = pd.DataFrame(dictionary).T
  dict_df.reset_index(inplace=True)
  dict_df['index'] = dict_df['index'].str[2:]
  dict_df = dict_df.drop(columns=['model'])

  dict_df.rename(columns={'index': 'Model name'}, inplace=True)

  return pd.merge(dict_df, df, on='Model name', how='inner')

# %%
A100_res = combine_dfs(A100_files, llm_A100)
A40_res = combine_dfs(A40_files, llm_A40)
V100_res = combine_dfs(V100_files, llm_V100)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-143-b1accde3484e>", line 1, in <cell line: 1>
#     A100_res = combine_dfs(A100_files, llm_A100)
#   File "<ipython-input-142-b65dd129b149>", line 5, in combine_dfs
#     dict_df = dict_df.drop(columns=['model'])
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 5399, in drop
#     return super().drop(
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/generic.py", line 4505, in drop
#     obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/generic.py", line 4546, in _drop_axis
#     new_axis = axis.drop(labels, errors=errors)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 6934, in drop
#     raise KeyError(f"{list(labels[mask])} not found in axis")
# KeyError: "['model'] not found in axis"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-143-b1accde3484e>", line 1, in <cell line: 1>
#     A100_res = combine_dfs(A100_files, llm_A100)
#   File "<ipython-input-142-b65dd129b149>", line 5, in combine_dfs
#     dict_df = dict_df.drop(columns=['model'])
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 5399, in drop
#     return super().drop(
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/generic.py", line 4505, in drop
#     obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/generic.py", line 4546, in _drop_axis
#     new_axis = axis.drop(labels, errors=errors)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 6934, in drop
#     raise KeyError(f"{list(labels[mask])} not found in axis")
# KeyError: "['model'] not found in axis"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-143-b1accde3484e>", line 1, in <cell line: 1>
#     A100_res = combine_dfs(A100_files, llm_A100)
#   File "<ipython-input-142-b65dd129b149>", line 5, in combine_dfs
#     dict_df = dict_df.drop(columns=['model'])
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 5399, in drop
#     return super().drop(
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/generic.py", line 4505, in drop
#     obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/generic.py", line 4546, in _drop_axis
#     new_axis = axis.drop(labels, errors=errors)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 6934, in drop
#     raise KeyError(f"{list(labels[mask])} not found in axis")
# KeyError: "['model'] not found in axis"
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
result_df = pd.concat([A100_res, A40_res, V100_res], ignore_index=True)

# %% [markdown]
# ##hi

# %%
result_df

# %%
X = result_df.iloc[:, -10:]
X = pd.get_dummies(X, columns = ['model type', 'type of attention operation', 'torch_dtype', 'gpu model'])

y = result_df['linear X']

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=2, weights="uniform")
imputer.fit_transform(X)
# Out:
# array([[ 7., 32., 32., ...,  1.,  0.,  0.],
#        [ 7., 32., 32., ...,  1.,  0.,  0.],
#        [ 7., 32., 32., ...,  1.,  0.,  0.],
#        ...,
#        [ 3., 24., 32., ...,  0.,  0.,  1.],
#        [12., 36., 40., ...,  0.,  0.,  1.],
#        [13., 40., 40., ...,  0.,  0.,  1.]])

# %%
X = X.astype(float)
X.dtypes
# Out:
# # of parameters (billions)           float64
# # of transformer layers              float64
# # of attention heads                 float64
# hidden dimension                     float64
# ffn intermediate dimension           float64
# vocab size                           float64
# model type_bloom                     float64
# model type_gpt_neox                  float64
# model type_gpt_neox                  float64
# model type_llama                     float64
# model type_t5                        float64
# type of attention operation_gelu     float64
# type of attention operation_gelu     float64
# type of attention operation_silu     float64
# torch_dtype_bfloat16                 float64
# torch_dtype_float16                  float64
# torch_dtype_float16                  float64
# torch_dtype_float16??                float64
# torch_dtype_float32                  float64
# torch_dtype_float64                  float64
# gpu model_A100                       float64
# gpu model_A40                        float64
# gpu model_V100                       float64
# dtype: object

# %%
sm.OLS(y, imputer.fit_transform(X)).fit()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-155-0811b7ca5487>", line 1, in <cell line: 1>
#     sm.OLS(y, imputer.fit_transform(X)).fit()
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py", line 922, in __init__
#     super(OLS, self).__init__(endog, exog, missing=missing,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py", line 748, in __init__
#     super(WLS, self).__init__(endog, exog, missing=missing,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py", line 202, in __init__
#     super(RegressionModel, self).__init__(endog, exog, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py", line 270, in __init__
#     super().__init__(endog, exog, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py", line 95, in __init__
#     self.data = self._handle_data(endog, exog, missing, hasconst,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py", line 135, in _handle_data
#     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py", line 675, in handle_data
#     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py", line 84, in __init__
#     self.endog, self.exog = self._convert_endog_exog(endog, exog)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py", line 509, in _convert_endog_exog
#     raise ValueError("Pandas data cast to numpy dtype of object. "
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-155-0811b7ca5487>", line 1, in <cell line: 1>
#     sm.OLS(y, imputer.fit_transform(X)).fit()
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py", line 922, in __init__
#     super(OLS, self).__init__(endog, exog, missing=missing,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py", line 748, in __init__
#     super(WLS, self).__init__(endog, exog, missing=missing,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py", line 202, in __init__
#     super(RegressionModel, self).__init__(endog, exog, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py", line 270, in __init__
#     super().__init__(endog, exog, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py", line 95, in __init__
#     self.data = self._handle_data(endog, exog, missing, hasconst,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py", line 135, in _handle_data
#     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py", line 675, in handle_data
#     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py", line 84, in __init__
#     self.endog, self.exog = self._convert_endog_exog(endog, exog)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py", line 509, in _convert_endog_exog
#     raise ValueError("Pandas data cast to numpy dtype of object. "
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-155-0811b7ca5487>", line 1, in <cell line: 1>
#     sm.OLS(y, imputer.fit_transform(X)).fit()
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py", line 922, in __init__
#     super(OLS, self).__init__(endog, exog, missing=missing,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py", line 748, in __init__
#     super(WLS, self).__init__(endog, exog, missing=missing,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py", line 202, in __init__
#     super(RegressionModel, self).__init__(endog, exog, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py", line 270, in __init__
#     super().__init__(endog, exog, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py", line 95, in __init__
#     self.data = self._handle_data(endog, exog, missing, hasconst,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py", line 135, in _handle_data
#     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py", line 675, in handle_data
#     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py", line 84, in __init__
#     self.endog, self.exog = self._convert_endog_exog(endog, exog)
#   File "/usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py", line 509, in _convert_endog_exog
#     raise ValueError("Pandas data cast to numpy dtype of object. "
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
